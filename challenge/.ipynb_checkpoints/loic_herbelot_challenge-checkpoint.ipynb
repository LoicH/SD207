# %% [markdown]
# # Challenge SD207 - 2017
#
# Acoustic scene classification
#
#
# # Data processing before classification:
#
# We take the samples, we extract the MFCC sequence of these files to represent audio files with vectors (matrix in fact). We will then do the classifying on these data.

# %%
import os
import re
import numpy as np
import pandas as pd
import librosa
from IPython.display import clear_output

# Constants:
data_home = "." #"/tsi/plato/sons/sd207"
training_file = 'audio/train.txt'
valid_file = 'audio/dev.txt'
n_vectors = 10 # Each audio file will be represented by [n_vectors] vectors (default value: 1296)
n_coefs = 20 # We will keep [n_coefs] MFC coefficients.

labels_numbers = {"beach": 0,
"bus": 1,
"cafe/restaurant": 2,
"car": 3,
"city_center": 4,
"forest_path": 5,
"grocery_store": 6,
"home": 7,
"library": 8,
"metro_station": 9,
"office": 10,
"park": 11,
"residential_area": 12,
"train": 13,
"tram": 14}

# Loading text files into pd.Dataframes
training_set = pd.read_csv(data_home + '/' + training_file, sep='\s+', 
                           dtype=str, names=['filename', 'label'])
testing_set    = pd.read_csv(data_home + '/' + valid_file, sep='\s+', 
                           dtype=str, names=['filename', 'label'])

unknown_set    = pd.read_csv(data_home + '/test_files.txt', sep='\s+', 
                           dtype=str, names=['filename'])

print("Training set: \n ", training_set[:10])
print("...\n(%d samples)" % len(training_set))
print("\nTesting set:\n", testing_set[:10])
print("...\n(%d samples)" % len(testing_set))
print("\nUnknown set: \n ", unknown_set[:10])
print("...\n(%d samples)" % len(unknown_set))
# Out:
# Training set:
#                    filename  label
# 0     audio/b010_0_30.wav  beach
# 1    audio/b010_60_90.wav  beach
# 2  audio/b010_150_180.wav  beach
# 3    audio/b010_30_60.wav  beach
# 4  audio/b010_120_150.wav  beach
# 5  audio/b022_120_150.wav  beach
# 6    audio/b022_60_90.wav  beach
# 7  audio/b022_180_210.wav  beach
# 8    audio/b022_30_60.wav  beach
# 9   audio/b022_90_120.wav  beach
# ...
# (582 samples)
#
# Testing set:
#                   filename  label
# 0    audio/b021_30_60.wav  beach
# 1  audio/b021_150_180.wav  beach
# 2   audio/b021_90_120.wav  beach
# 3  audio/b021_120_150.wav  beach
# 4    audio/b021_60_90.wav  beach
# 5  audio/b021_180_210.wav  beach
# 6     audio/b021_0_30.wav  beach
# 7  audio/b019_180_210.wav  beach
# 8  audio/b019_120_150.wav  beach
# 9   audio/b019_90_120.wav  beach
# ...
# (290 samples)
#
# Unknown set:
#                    filename
# 0     audio/b053_0_30.wav
# 1   audio/b035_90_120.wav
# 2  audio/b089_210_240.wav
# 3    audio/a034_30_60.wav
# 4  audio/a045_150_180.wav
# 5   audio/a058_90_120.wav
# 6    audio/b029_60_90.wav
# 7    audio/a079_30_60.wav
# 8  audio/b055_137_167.wav
# 9  audio/b049_150_180.wav
# ...
# (298 samples)

# %%
# Load the audio files:

def get_descr(path, n_coef, n_vectors):
    """Returns a matrix description of an audio file.
    
    :param path: The path to the audio file
    :param n_coef: The numbers of MFC coefficients
    :param n_vectors: number of vectors that will represent the audio file.
        This is the number of frames we will split the audio file into.
    
    :return: ndarray of shape (n_coefs, n_vectors) 
        where each column is a MFCC sequence of a frame in the audio file."""
    y, sr = librosa.load(path)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_coef)
    # We have to many columns in [mfcc], we will stack them into [X]
    X = np.zeros((n_coef, n_vectors))
    # Numbers of samples we will take to make one vector
    p = mfcc.shape[1] // n_vectors 
    for i in range(n_vectors-1):
        # We collapse the [p] vectors into one single column in [X]
        X[:,i] = np.mean(mfcc[:,i*p:(i+1)*p], axis=1)
    # Last vector:
    i += 1
    X[:,i] = np.mean(mfcc[:,i*p:], axis=1)
    return X


def _populate_training(data_home, training_set, n_vectors, n_coefs):
    """ Create the data matrix and the label vectors for the samples 
    in the training set.
    
    :param data_home: The path to the directory containing the files
    :param training_set: The dataframe linking each filename to its label
    :param n_vectors: number of vectors for each sample
    :param n_coefs: Numbers of MFC coefficients for each sample
    
    :return: X [shape=(n_coefs, N_samples*n_vectors)], y [shape=(N_samples*n_vectors,)]
            The data matrix and the labels for each vector"""
    n_samples = len(training_set)
    data = np.zeros((n_coefs, n_samples * n_vectors))
    labels = np.zeros(n_samples * n_vectors, dtype=object)
    for i, row in training_set.iterrows():
        if i%10==0:
            print("Processed samples: %d/%d..." % (i, n_samples))
        filename, label = row.filename, row.label
        descr = get_descr(data_home + '/' + filename, n_coefs, n_vectors)
        data[:,i*n_vectors:(i+1)*n_vectors] = descr
        labels[i*n_vectors:(i+1)*n_vectors] = label
    print("Done processing")
    return data, labels



def get_data_filename(descr, n_coefs, n_vectors):
    """Returns the file names for the saved data.
    
    :return: set, label
        set   - filename for the audio data
        label - filename for the labels"""
    return ('{0}_set_{1}coef_{2}vect.txt'.format(descr, n_coefs, n_vectors),
            '{0}_labels_{1}coef_{2}vect.txt'.format(descr, n_coefs, n_vectors))

def extract_features(dataframe, n_vectors, n_coefs, data_home=".",  saving='autosave'):
    """ Extract the features from a batch of audio files and saves them in a file.
    
    :param dataframa: pd.DataFrame, linking filename to labels
    :param data_home: The path to the audio files
    :param n_vectors: The number of vectors that represent an audio sample
    :param n_coefs:   The number of MFC coefficients to extract
    :param saving:    The description of the filename saving the data.
                      This function will save two files: the data from 
                      the audio files, and the labels.
        
    :return: data, labels
        - data: ndarray of shape (n_coefs, N_samples * n_vectors) containing 
                the MFC coefficients for each audio samples
        - labels: ndarray of shape (N_samples * n_vectors, ) containing the labels
                for each vector."""
    # Checking if the data is already extracted:
    #TODO
    filename_data, filename_labels = get_data_filename(saving, n_coefs, n_vectors)

    if filename_data not in os.listdir() or filename_labels not in os.listdir():
        print("%s or %s not found in the folder." % (filename_data, filename_labels))
        # Not already processed:
        print("First time processing audio files.")
        n_samples = len(dataframe)
        data = np.zeros((n_coefs, n_samples * n_vectors))
        labels = np.zeros(n_samples * n_vectors, dtype=object)
        for i, row in training_set.iterrows():
            if i%10==0:
                print("Processed samples: %d/%d..." % (i, n_samples))
                clear_output(wait=True)
            filename, label = row.filename, row.label
            descr = get_descr(data_home + '/' + filename, n_coefs, n_vectors)
            data[:,i*n_vectors:(i+1)*n_vectors] = descr
            labels[i*n_vectors:(i+1)*n_vectors] = label
        print("Done processing")
        print("You can check the shape of the data and labels: ",data.shape, labels.shape)
        print("Saving the processed data.")
        np.savetxt(filename_data, data)
        np.savetxt(filename_labels, labels,  fmt="%s")
    else:
        print("Audio files already processed, retrieving the file.")
        data = np.loadtxt(filename_data)
        labels = np.array(pd.read_csv(filename_labels, header=None)).ravel()
        print(data.shape, labels.shape)
        print("Overview of labels: ",labels)

    return data, labels
        
# TODO: threads

data, labels = extract_features(training_set, n_vectors, n_coefs, data_home=data_home, saving="training")
counts = np.unique(labels, return_counts=True)
for i in range(len(counts[0])):
    print("%s: %d" % (counts[0][i], counts[1][i]))
# Out:
# Audio files already processed, retrieving the file.
# (20, 5820) (5820,)
# Overview of labels:  ['beach' 'beach' 'beach' ..., 'tram' 'tram' 'tram']
# beach: 380
# bus: 390
# cafe/restaurant: 380
# car: 400
# city_center: 400
# forest_path: 420
# grocery_store: 380
# home: 400
# library: 400
# metro_station: 380
# office: 370
# park: 400
# residential_area: 380
# train: 360
# tram: 380

# %%
# Checking if a random sample is well described in the data matrix:
rand_id = np.random.randint(0, len(training_set))
filename = training_set.loc[rand_id, 'filename']
#TODO: finish
print("Checking with sample: %s" % filename)
y, sr = librosa.load(path = filename)
mfcc = librosa.feature.mfcc(y, sr, n_mfcc=n_coefs)
n_cols = mfcc.shape[1]
p = n_cols//n_vectors

np.set_printoptions(precision=2, threshold=5, formatter={'float_kind':lambda x:"%.2f" % x})

print("Checking the MFCC sequence against the computed data matrix")
rand_ints = np.random.permutation(n_coefs)[:5] # random lines
print("rand_id:", rand_id)
print("rand_ints:", rand_ints)
print("data: ", data.shape)
for i in range(n_vectors):
    print("-"*20)
    print("MFCC:")
    print(mfcc[rand_ints,i*p:(i+1)*p])
    print("Computed mean: ", np.mean(mfcc[rand_ints,i*p:(i+1)*p], axis=1))
    print("\ndata[%d]:" % (rand_id*n_vectors + i))
    print("(Each term should be the mean of the corresponding line)")
    print(data[rand_ints, rand_id*n_vectors + i])
# Out:
# Checking with sample: audio/b082_150_180.wav
# Checking the MFCC sequence against the computed data matrix
# rand_id: 281
# rand_ints: [18 14 17 13  0]
# data:  (20, 5820)
# --------------------
# MFCC:
# [[1.35 3.11 -4.74 ..., -2.60 -3.46 -4.60]
#  [2.58 5.48 4.46 ..., 10.82 5.57 4.45]
#  [2.92 5.05 -1.98 ..., 1.79 -1.49 -3.06]
#  [-4.34 6.40 11.92 ..., 6.60 7.04 9.45]
#  [-370.15 -369.59 -377.41 ..., -383.53 -386.30 -397.02]]
# Computed mean:  [-2.46 7.07 1.17 3.10 -377.36]
#
# data[2810]:
# (Each term should be the mean of the corresponding line)
# [-2.44 7.09 1.22 3.03 -377.21]
# --------------------
# MFCC:
# [[-3.69 -5.92 -7.05 ..., -7.73 -1.70 -0.67]
#  [15.22 14.68 8.22 ..., 12.71 9.60 3.03]
#  [-1.51 -0.67 -4.18 ..., -3.08 -2.36 2.20]
#  [8.81 1.48 -1.60 ..., 2.65 2.53 -3.25]
#  [-378.76 -353.35 -340.50 ..., -420.61 -424.99 -423.57]]
# Computed mean:  [-3.46 8.44 0.50 2.53 -378.59]
#
# data[2811]:
# (Each term should be the mean of the corresponding line)
# [-3.48 8.49 0.48 2.57 -378.24]
# --------------------
# MFCC:
# [[-4.53 -0.26 6.32 ..., 1.42 5.66 3.97]
#  [7.48 7.00 2.98 ..., 10.38 3.78 2.08]
#  [-3.09 -3.52 2.22 ..., -2.65 -3.50 1.80]
#  [-2.01 0.27 1.83 ..., 2.63 3.50 0.34]
#  [-424.22 -428.43 -432.60 ..., -447.81 -448.94 -439.47]]
# Computed mean:  [0.24 5.89 0.37 1.99 -445.17]
#
# data[2812]:
# (Each term should be the mean of the corresponding line)
# [0.21 5.91 0.34 1.99 -445.20]
# --------------------
# MFCC:
# [[4.23 -0.13 3.54 ..., -1.33 -1.83 0.66]
#  [3.64 2.50 3.17 ..., 19.59 14.78 10.10]
#  [5.15 0.96 2.10 ..., 7.40 8.64 5.73]
#  [2.13 3.20 2.16 ..., -2.15 -5.19 -2.47]
#  [-439.41 -448.54 -460.65 ..., -299.64 -331.96 -351.78]]
# Computed mean:  [3.79 5.16 2.99 2.49 -441.77]
#
# data[2813]:
# (Each term should be the mean of the corresponding line)
# [3.80 5.11 2.97 2.54 -442.46]
# --------------------
# MFCC:
# [[0.74 1.75 1.94 ..., 3.05 3.45 2.45]
#  [2.71 -4.28 -0.32 ..., -0.39 -1.12 2.58]
#  [8.21 12.60 9.69 ..., 3.02 5.79 4.59]
#  [-1.64 -6.99 -7.91 ..., 1.26 1.47 6.94]
#  [-369.73 -382.44 -387.72 ..., -412.83 -409.43 -406.52]]
# Computed mean:  [2.79 2.79 3.04 2.34 -396.63]
#
# data[2814]:
# (Each term should be the mean of the corresponding line)
# [2.79 2.79 3.02 2.31 -396.54]
# --------------------
# MFCC:
# [[1.22 4.40 11.40 ..., -0.66 -6.85 -4.97]
#  [5.01 -0.35 1.34 ..., 3.92 4.53 4.77]
#  [3.04 6.50 4.41 ..., -2.16 -6.12 -0.96]
#  [6.92 -0.99 7.34 ..., 5.91 6.85 7.60]
#  [-411.20 -416.49 -419.64 ..., -405.59 -406.40 -407.65]]
# Computed mean:  [-1.04 3.62 -0.54 6.43 -409.26]
#
# data[2815]:
# (Each term should be the mean of the corresponding line)
# [-1.00 3.61 -0.53 6.42 -409.29]
# --------------------
# MFCC:
# [[-4.74 -9.91 -8.77 ..., 7.68 4.38 4.73]
#  [1.71 -1.57 1.65 ..., -1.44 -3.62 -6.79]
#  [0.94 -6.53 -7.61 ..., 0.60 0.57 0.80]
#  [6.32 4.13 4.31 ..., -2.05 -1.20 -3.56]
#  [-406.57 -409.69 -414.65 ..., -471.24 -462.76 -460.47]]
# Computed mean:  [0.99 3.55 2.25 0.74 -395.73]
#
# data[2816]:
# (Each term should be the mean of the corresponding line)
# [0.96 3.63 2.27 0.79 -395.23]
# --------------------
# MFCC:
# [[6.71 2.71 0.41 ..., 7.23 7.07 6.94]
#  [-5.64 -3.96 -0.27 ..., 5.07 2.91 0.86]
#  [3.59 -2.85 -0.29 ..., 5.38 3.62 5.08]
#  [-4.61 -2.63 -3.60 ..., -2.10 -2.39 -1.36]
#  [-463.43 -467.11 -472.78 ..., -490.04 -487.90 -486.06]]
# Computed mean:  [3.74 1.23 -2.04 -1.21 -472.07]
#
# data[2817]:
# (Each term should be the mean of the corresponding line)
# [3.72 1.24 -2.12 -1.21 -471.95]
# --------------------
# MFCC:
# [[8.55 7.43 3.22 ..., 1.86 3.36 0.24]
#  [2.27 -2.28 -0.23 ..., 9.04 1.97 5.30]
#  [6.05 4.39 0.01 ..., 4.87 0.32 -2.89]
#  [-0.11 -3.89 -2.86 ..., 6.51 -0.40 0.49]
#  [-486.58 -487.80 -484.70 ..., -473.75 -473.97 -462.43]]
# Computed mean:  [2.14 3.39 1.94 0.27 -471.47]
#
# data[2818]:
# (Each term should be the mean of the corresponding line)
# [2.16 3.37 2.00 0.29 -471.51]
# --------------------
# MFCC:
# [[-4.89 -6.58 2.97 ..., -6.34 -7.97 -8.34]
#  [8.81 12.11 10.63 ..., 4.89 7.54 9.74]
#  [-3.01 -5.54 0.17 ..., -3.68 -2.44 -7.44]
#  [4.01 5.43 4.07 ..., 5.69 0.91 -1.39]
#  [-445.93 -443.24 -451.81 ..., -410.74 -411.61 -402.12]]
# Computed mean:  [-1.16 4.27 -0.95 2.27 -432.82]
#
# data[2819]:
# (Each term should be the mean of the corresponding line)
# [-1.31 4.33 -0.87 2.16 -432.06]

# %% [markdown]
# ## Let's do the actual training and prediction !

# %%
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVR

import time

X = data.T
y = np.array([labels_numbers[name] for name in labels])



def most_frequent(array):
    unique, counts = np.unique(array, return_counts=True)
    return unique[counts.argmax()]

def predict(path, votes, clf, n_coefs=20, n_vect=10, verbose=False):
    """ Return the number of the assumed class of an audio file.
    
    :param path: The path to the file
    :param votes: A dictionary {number: label} that represents the association
        between the meaningful numbers returned by the classifier
        and the actual classes of the data.
    :param clf: The classifier object
    :param n_coefs: Number of MFCC coefficients to extract from the audio file
    :param n_vect: Number of vectors (audio frames) the audio file should be 
            split into
    
    :return: The number of the assumed class of this audio file."""
    descr = get_descr(path, n_coefs, n_vect) # n_features * n_samples
    predictions = clf.predict(descr.T).round()
    selection = most_frequent(predictions)
    #TODO: take all the predictions and take weights.
    if verbose:
        print("Predictions for sample %s:" % path)
        print(predictions)
        print("%s seems to belong in class n. '%d'" % (path, selection))
    return votes[selection]
  

def get_votes(labels, predictions, verbose=False):
    """ Return the names of the classes returned by the classifer.
    :param labels: The labels names
    :param predictions: The predictions for the training set
    :return: a dictionary associating classes to label names"""
    corresp = {} # dictionary {number: label name}
    round_pred = predictions.round()
    for i in np.unique(round_pred):
        # The group of all labels that were assigned to the number i
        group = labels[round_pred == i] 
        if verbose:
            print("Samples that were assigned to clas %d came from labels:"% i)
            print(np.unique(group, return_counts=True))
        vote = most_frequent(group)
        corresp[i] = vote
    return corresp

permut = np.random.permutation(len(X))
X = X[permut]
y = y[permut]
labels_permut = labels[permut]

regressors = {'knn':{'clf': KNeighborsRegressor(),
                     'params': {'n_neighbors': np.arange(1, 20, 10, dtype=int),
                              'weights': ('uniform', 'distance',),
                              'algorithm': ('auto', 'ball_tree', )}
                    },
              'gmm':{'clf': GaussianMixture(n_components=16),
                     'params': {'n_components':[16],
                                'covariance_type': ('full', 'tied', 'diag', 'spherical'),
                                'tol': np.logspace(-3, -1, 6)}
                    },
              'svr':{'clf':SVR(),
                     'params': {'C' : np.logspace(-1,0,3),
                                'epsilon' : np.logspace(-2,0,3),
                                'kernel' : ('rbf', )}# 'poly', 'rbf')}
                    }
}


choice = regressors['knn']
gridsearch = True

if gridsearch:
    cv = GridSearchCV(choice['clf'], choice['params'], verbose=2, n_jobs=-1)
    # Resetting the print options:
    np.set_printoptions(edgeitems=3,infstr='inf',
                        linewidth=75, nanstr='nan', precision=8,
                        suppress=False, threshold=1000, formatter=None)
    t0 = time.time()
    print("Fitting the GridSearch classifier:")
    cv.fit(X, y=y)
    print("Finished in %.2f s." % (time.time() - t0))
    print("Best parameters: ",cv.best_params_)
    best_clf = cv.best_estimator_
else:
    best_clf = choice['clf'].fit(X, y)
    
print("Getting the predictions for the training class")
clf_labels = best_clf.predict(X)

print("Getting the votes:")
votes = get_votes(labels_permut, clf_labels)
print(votes)
# Out:
# Fitting the GridSearch classifier:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV] weights=uniform, algorithm=auto, n_neighbors=1 ..................
# [CV] weights=uniform, algorithm=auto, n_neighbors=1 ..................
# [CV] weights=uniform, algorithm=auto, n_neighbors=1 ..................
# [CV] weights=distance, algorithm=auto, n_neighbors=1 .................
# [CV] ... weights=uniform, algorithm=auto, n_neighbors=1, total=   0.1s
# [CV] ... weights=uniform, algorithm=auto, n_neighbors=1, total=   0.1s
# [CV] weights=distance, algorithm=auto, n_neighbors=1 .................
# [CV] ... weights=uniform, algorithm=auto, n_neighbors=1, total=   0.1s
# [CV] .. weights=distance, algorithm=auto, n_neighbors=1, total=   0.1s
# [CV] weights=uniform, algorithm=auto, n_neighbors=11 .................
# [CV] weights=distance, algorithm=auto, n_neighbors=1 .................
# [CV] weights=uniform, algorithm=auto, n_neighbors=11 .................
# [CV] .. weights=distance, algorithm=auto, n_neighbors=1, total=   0.0s
# [CV] weights=uniform, algorithm=auto, n_neighbors=11 .................
# [CV] .. weights=distance, algorithm=auto, n_neighbors=1, total=   0.1s
# [CV] weights=distance, algorithm=auto, n_neighbors=11 ................
# [CV] .. weights=uniform, algorithm=auto, n_neighbors=11, total=   0.1s
# [CV] weights=uniform, algorithm=ball_tree, n_neighbors=1 .............
# [CV] .. weights=uniform, algorithm=auto, n_neighbors=11, total=   0.1s
# [CV] weights=uniform, algorithm=ball_tree, n_neighbors=1 .............
# [CV] .. weights=uniform, algorithm=auto, n_neighbors=11, total=   0.1s
# [CV] weights=distance, algorithm=auto, n_neighbors=11 ................
# [CV] . weights=distance, algorithm=auto, n_neighbors=11, total=   0.1s
# [CV] weights=distance, algorithm=auto, n_neighbors=11 ................
# [CV]  weights=uniform, algorithm=ball_tree, n_neighbors=1, total=   0.1s
# [CV] weights=uniform, algorithm=ball_tree, n_neighbors=1 .............
# [CV]  weights=uniform, algorithm=ball_tree, n_neighbors=1, total=   0.2s
# [CV] weights=distance, algorithm=ball_tree, n_neighbors=1 ............
# [CV] . weights=distance, algorithm=auto, n_neighbors=11, total=   0.1s
# [CV] weights=distance, algorithm=ball_tree, n_neighbors=1 ............
# [CV] . weights=distance, algorithm=auto, n_neighbors=11, total=   0.1s
# [CV] weights=uniform, algorithm=ball_tree, n_neighbors=11 ............
# [CV]  weights=uniform, algorithm=ball_tree, n_neighbors=1, total=   0.1s
# [CV] weights=uniform, algorithm=ball_tree, n_neighbors=11 ............
# [CV]  weights=distance, algorithm=ball_tree, n_neighbors=1, total=   0.1s
# [CV] weights=distance, algorithm=ball_tree, n_neighbors=1 ............
# [CV]  weights=distance, algorithm=ball_tree, n_neighbors=1, total=   0.1s
# [CV] weights=distance, algorithm=ball_tree, n_neighbors=11 ...........
# [CV]  weights=uniform, algorithm=ball_tree, n_neighbors=11, total=   0.1s
# [CV] weights=uniform, algorithm=ball_tree, n_neighbors=11 ............
# [CV]  weights=distance, algorithm=ball_tree, n_neighbors=1, total=   0.1s
# [CV]  weights=uniform, algorithm=ball_tree, n_neighbors=11, total=   0.2s
# [CV] weights=distance, algorithm=ball_tree, n_neighbors=11 ...........
# [CV]  weights=distance, algorithm=ball_tree, n_neighbors=11, total=   0.2s
# [CV] weights=distance, algorithm=ball_tree, n_neighbors=11 ...........
# [CV]  weights=distance, algorithm=ball_tree, n_neighbors=11, total=   0.1s
# [CV]  weights=uniform, algorithm=ball_tree, n_neighbors=11, total=   0.2s
# [CV]  weights=distance, algorithm=ball_tree, n_neighbors=11, total=   0.1s
# Finished in 2.11 s.
# Best parameters:  {'weights': 'uniform', 'algorithm': 'auto', 'n_neighbors': 1}
# Getting the predictions for the training class
# Getting the votes:
# {0.0: 'beach', 1.0: 'bus', 2.0: 'cafe/restaurant', 3.0: 'car', 4.0: 'city_center', 5.0: 'forest_path', 6.0: 'grocery_store', 7.0: 'home', 8.0: 'library', 9.0: 'metro_station', 10.0: 'office', 11.0: 'park', 12.0: 'residential_area', 13.0: 'train', 14.0: 'tram'}
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    2.0s finished

# %%
print(labels_numbers)
for k,v in votes.items():
    if 0 <= k <= 14:
        print("Label: '%15s', real number: %2d, guessed number: %2d" % (v, labels_numbers[v], k))
successes = 0

for i, row in testing_set.iterrows():
    prediction = predict(row.filename, votes, best_clf, n_coefs=n_coefs, n_vect=n_vectors)
    if prediction == row.label:
        successes += 1
        print('✓', end=' ')
    else:
        print('✗', end=' ')
    print("Prediction: '%s', should be '%s'" % (prediction, row.label))
    print("\tSo far, success rate: %d/%d (%.2f %%)" % (successes, i+1, successes/(i+1) * 100))
print("Done. Success rate: %d/%d (%.2f %%)" % (successes, i+1, successes/(i+1) * 100))
# Out:
# {'park': 11, 'bus': 1, 'office': 10, 'forest_path': 5, 'tram': 14, 'metro_station': 9, 'library': 8, 'car': 3, 'train': 13, 'cafe/restaurant': 2, 'city_center': 4, 'beach': 0, 'home': 7, 'residential_area': 12, 'grocery_store': 6}
# Label: '          beach', real number:  0, guessed number:  0
# Label: '            bus', real number:  1, guessed number:  1
# Label: 'cafe/restaurant', real number:  2, guessed number:  2
# Label: '            car', real number:  3, guessed number:  3
# Label: '    city_center', real number:  4, guessed number:  4
# Label: '    forest_path', real number:  5, guessed number:  5
# Label: '  grocery_store', real number:  6, guessed number:  6
# Label: '           home', real number:  7, guessed number:  7
# Label: '        library', real number:  8, guessed number:  8
# Label: '  metro_station', real number:  9, guessed number:  9
# Label: '         office', real number: 10, guessed number: 10
# Label: '           park', real number: 11, guessed number: 11
# Label: 'residential_area', real number: 12, guessed number: 12
# Label: '          train', real number: 13, guessed number: 13
# Label: '           tram', real number: 14, guessed number: 14
# ✗ Prediction: 'grocery_store', should be 'beach'
# 	So far, success rate: 0/1 (0.00 %)
# ✓ Prediction: 'beach', should be 'beach'
# 	So far, success rate: 1/2 (50.00 %)
# ✓ Prediction: 'beach', should be 'beach'
# 	So far, success rate: 2/3 (66.67 %)
# ✓ Prediction: 'beach', should be 'beach'
# 	So far, success rate: 3/4 (75.00 %)
# ✗ Prediction: 'grocery_store', should be 'beach'
# 	So far, success rate: 3/5 (60.00 %)
# ✓ Prediction: 'beach', should be 'beach'
# 	So far, success rate: 4/6 (66.67 %)
# ✗ Prediction: 'grocery_store', should be 'beach'
# 	So far, success rate: 4/7 (57.14 %)
# ✗ Prediction: 'residential_area', should be 'beach'
# 	So far, success rate: 4/8 (50.00 %)
# ✗ Prediction: 'residential_area', should be 'beach'
# 	So far, success rate: 4/9 (44.44 %)
# ✗ Prediction: 'city_center', should be 'beach'
# 	So far, success rate: 4/10 (40.00 %)
# ✗ Prediction: 'city_center', should be 'beach'
# 	So far, success rate: 4/11 (36.36 %)
# ✗ Prediction: 'city_center', should be 'beach'
# 	So far, success rate: 4/12 (33.33 %)
# ✗ Prediction: 'residential_area', should be 'beach'
# 	So far, success rate: 4/13 (30.77 %)
# ✗ Prediction: 'city_center', should be 'beach'
# 	So far, success rate: 4/14 (28.57 %)
# ✗ Prediction: 'residential_area', should be 'beach'
# 	So far, success rate: 4/15 (26.67 %)
# ✓ Prediction: 'beach', should be 'beach'
# 	So far, success rate: 5/16 (31.25 %)
# ✗ Prediction: 'residential_area', should be 'beach'
# 	So far, success rate: 5/17 (29.41 %)
# ✓ Prediction: 'beach', should be 'beach'
# 	So far, success rate: 6/18 (33.33 %)
# ✗ Prediction: 'residential_area', should be 'beach'
# 	So far, success rate: 6/19 (31.58 %)
# ✗ Prediction: 'cafe/restaurant', should be 'beach'
# 	So far, success rate: 6/20 (30.00 %)
# ✗ Prediction: 'residential_area', should be 'beach'
# 	So far, success rate: 6/21 (28.57 %)
# ✗ Prediction: 'tram', should be 'bus'
# 	So far, success rate: 6/22 (27.27 %)
# ✗ Prediction: 'tram', should be 'bus'
# 	So far, success rate: 6/23 (26.09 %)
# ✗ Prediction: 'tram', should be 'bus'
# 	So far, success rate: 6/24 (25.00 %)
# ✗ Prediction: 'tram', should be 'bus'
# 	So far, success rate: 6/25 (24.00 %)
# ✓ Prediction: 'bus', should be 'bus'
# 	So far, success rate: 7/26 (26.92 %)
# ✓ Prediction: 'bus', should be 'bus'
# 	So far, success rate: 8/27 (29.63 %)
# ✗ Prediction: 'train', should be 'bus'
# 	So far, success rate: 8/28 (28.57 %)
# ✗ Prediction: 'train', should be 'bus'
# 	So far, success rate: 8/29 (27.59 %)
# ✗ Prediction: 'train', should be 'bus'
# 	So far, success rate: 8/30 (26.67 %)
# ✗ Prediction: 'train', should be 'bus'
# 	So far, success rate: 8/31 (25.81 %)
# ✗ Prediction: 'train', should be 'bus'
# 	So far, success rate: 8/32 (25.00 %)
# ✗ Prediction: 'train', should be 'bus'
# 	So far, success rate: 8/33 (24.24 %)
# ✗ Prediction: 'train', should be 'bus'
# 	So far, success rate: 8/34 (23.53 %)
# ✗ Prediction: 'train', should be 'bus'
# 	So far, success rate: 8/35 (22.86 %)
# ✗ Prediction: 'train', should be 'bus'
# 	So far, success rate: 8/36 (22.22 %)
# ✗ Prediction: 'tram', should be 'bus'
# 	So far, success rate: 8/37 (21.62 %)
# ✗ Prediction: 'car', should be 'bus'
# 	So far, success rate: 8/38 (21.05 %)
# ✓ Prediction: 'bus', should be 'bus'
# 	So far, success rate: 9/39 (23.08 %)
# ✓ Prediction: 'bus', should be 'bus'
# 	So far, success rate: 10/40 (25.00 %)
# ✗ Prediction: 'tram', should be 'bus'
# 	So far, success rate: 10/41 (24.39 %)
# ✗ Prediction: 'metro_station', should be 'cafe/restaurant'
# 	So far, success rate: 10/42 (23.81 %)
# ✗ Prediction: 'metro_station', should be 'cafe/restaurant'
# 	So far, success rate: 10/43 (23.26 %)
# ✓ Prediction: 'cafe/restaurant', should be 'cafe/restaurant'
# 	So far, success rate: 11/44 (25.00 %)
# ✓ Prediction: 'cafe/restaurant', should be 'cafe/restaurant'
# 	So far, success rate: 12/45 (26.67 %)
# ✗ Prediction: 'metro_station', should be 'cafe/restaurant'
# 	So far, success rate: 12/46 (26.09 %)
# ✓ Prediction: 'cafe/restaurant', should be 'cafe/restaurant'
# 	So far, success rate: 13/47 (27.66 %)
# ✓ Prediction: 'cafe/restaurant', should be 'cafe/restaurant'
# 	So far, success rate: 14/48 (29.17 %)
# ✓ Prediction: 'cafe/restaurant', should be 'cafe/restaurant'
# 	So far, success rate: 15/49 (30.61 %)
# ✓ Prediction: 'cafe/restaurant', should be 'cafe/restaurant'
# 	So far, success rate: 16/50 (32.00 %)
# ✗ Prediction: 'metro_station', should be 'cafe/restaurant'
# 	So far, success rate: 16/51 (31.37 %)
# ✓ Prediction: 'cafe/restaurant', should be 'cafe/restaurant'
# 	So far, success rate: 17/52 (32.69 %)
# ✗ Prediction: 'grocery_store', should be 'cafe/restaurant'
# 	So far, success rate: 17/53 (32.08 %)
# ✗ Prediction: 'grocery_store', should be 'cafe/restaurant'
# 	So far, success rate: 17/54 (31.48 %)
# ✗ Prediction: 'grocery_store', should be 'cafe/restaurant'
# 	So far, success rate: 17/55 (30.91 %)
# ✗ Prediction: 'grocery_store', should be 'cafe/restaurant'
# 	So far, success rate: 17/56 (30.36 %)
# ✗ Prediction: 'grocery_store', should be 'cafe/restaurant'
# 	So far, success rate: 17/57 (29.82 %)
# ✗ Prediction: 'grocery_store', should be 'cafe/restaurant'
# 	So far, success rate: 17/58 (29.31 %)
# ✗ Prediction: 'grocery_store', should be 'cafe/restaurant'
# 	So far, success rate: 17/59 (28.81 %)
# ✗ Prediction: 'grocery_store', should be 'cafe/restaurant'
# 	So far, success rate: 17/60 (28.33 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 18/61 (29.51 %)
# ✗ Prediction: 'tram', should be 'car'
# 	So far, success rate: 18/62 (29.03 %)
# ✗ Prediction: 'tram', should be 'car'
# 	So far, success rate: 18/63 (28.57 %)
# ✗ Prediction: 'tram', should be 'car'
# 	So far, success rate: 18/64 (28.12 %)
# ✗ Prediction: 'tram', should be 'car'
# 	So far, success rate: 18/65 (27.69 %)
# ✗ Prediction: 'tram', should be 'car'
# 	So far, success rate: 18/66 (27.27 %)
# ✗ Prediction: 'tram', should be 'car'
# 	So far, success rate: 18/67 (26.87 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 19/68 (27.94 %)
# ✗ Prediction: 'beach', should be 'car'
# 	So far, success rate: 19/69 (27.54 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 20/70 (28.57 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 21/71 (29.58 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 22/72 (30.56 %)
# ✗ Prediction: 'tram', should be 'car'
# 	So far, success rate: 22/73 (30.14 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 23/74 (31.08 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 24/75 (32.00 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 25/76 (32.89 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 26/77 (33.77 %)
# ✗ Prediction: 'tram', should be 'car'
# 	So far, success rate: 26/78 (33.33 %)
# ✓ Prediction: 'car', should be 'car'
# 	So far, success rate: 27/79 (34.18 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 28/80 (35.00 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 29/81 (35.80 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 30/82 (36.59 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 31/83 (37.35 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 32/84 (38.10 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 33/85 (38.82 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 34/86 (39.53 %)
# ✗ Prediction: 'residential_area', should be 'city_center'
# 	So far, success rate: 34/87 (39.08 %)
# ✗ Prediction: 'residential_area', should be 'city_center'
# 	So far, success rate: 34/88 (38.64 %)
# ✗ Prediction: 'residential_area', should be 'city_center'
# 	So far, success rate: 34/89 (38.20 %)
# ✗ Prediction: 'residential_area', should be 'city_center'
# 	So far, success rate: 34/90 (37.78 %)
# ✗ Prediction: 'residential_area', should be 'city_center'
# 	So far, success rate: 34/91 (37.36 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 35/92 (38.04 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 36/93 (38.71 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 37/94 (39.36 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 38/95 (40.00 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 39/96 (40.62 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 40/97 (41.24 %)
# ✓ Prediction: 'city_center', should be 'city_center'
# 	So far, success rate: 41/98 (41.84 %)
# ✓ Prediction: 'forest_path', should be 'forest_path'
# 	So far, success rate: 42/99 (42.42 %)
# ✗ Prediction: 'park', should be 'forest_path'
# 	So far, success rate: 42/100 (42.00 %)
# ✗ Prediction: 'beach', should be 'forest_path'
# 	So far, success rate: 42/101 (41.58 %)
# ✓ Prediction: 'forest_path', should be 'forest_path'
# 	So far, success rate: 43/102 (42.16 %)
# ✓ Prediction: 'forest_path', should be 'forest_path'
# 	So far, success rate: 44/103 (42.72 %)
# ✗ Prediction: 'home', should be 'forest_path'
# 	So far, success rate: 44/104 (42.31 %)
# ✓ Prediction: 'forest_path', should be 'forest_path'
# 	So far, success rate: 45/105 (42.86 %)
# ✗ Prediction: 'home', should be 'forest_path'
# 	So far, success rate: 45/106 (42.45 %)
# ✓ Prediction: 'forest_path', should be 'forest_path'
# 	So far, success rate: 46/107 (42.99 %)
# ✗ Prediction: 'home', should be 'forest_path'
# 	So far, success rate: 46/108 (42.59 %)
# ✓ Prediction: 'forest_path', should be 'forest_path'
# 	So far, success rate: 47/109 (43.12 %)
# ✓ Prediction: 'forest_path', should be 'forest_path'
# 	So far, success rate: 48/110 (43.64 %)
# ✗ Prediction: 'home', should be 'forest_path'
# 	So far, success rate: 48/111 (43.24 %)
# ✗ Prediction: 'beach', should be 'forest_path'
# 	So far, success rate: 48/112 (42.86 %)
# ✓ Prediction: 'forest_path', should be 'forest_path'
# 	So far, success rate: 49/113 (43.36 %)
# ✗ Prediction: 'residential_area', should be 'forest_path'
# 	So far, success rate: 49/114 (42.98 %)
# ✗ Prediction: 'residential_area', should be 'forest_path'
# 	So far, success rate: 49/115 (42.61 %)
# ✗ Prediction: 'cafe/restaurant', should be 'forest_path'
# 	So far, success rate: 49/116 (42.24 %)
# ✗ Prediction: 'bus', should be 'grocery_store'
# 	So far, success rate: 49/117 (41.88 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 50/118 (42.37 %)
# ✗ Prediction: 'city_center', should be 'grocery_store'
# 	So far, success rate: 50/119 (42.02 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 51/120 (42.50 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 52/121 (42.98 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 53/122 (43.44 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 54/123 (43.90 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 55/124 (44.35 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 56/125 (44.80 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 57/126 (45.24 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 58/127 (45.67 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 59/128 (46.09 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 60/129 (46.51 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 61/130 (46.92 %)
# ✗ Prediction: 'park', should be 'grocery_store'
# 	So far, success rate: 61/131 (46.56 %)
# ✗ Prediction: 'metro_station', should be 'grocery_store'
# 	So far, success rate: 61/132 (46.21 %)
# ✓ Prediction: 'grocery_store', should be 'grocery_store'
# 	So far, success rate: 62/133 (46.62 %)
# ✗ Prediction: 'metro_station', should be 'grocery_store'
# 	So far, success rate: 62/134 (46.27 %)
# ✗ Prediction: 'cafe/restaurant', should be 'grocery_store'
# 	So far, success rate: 62/135 (45.93 %)
# ✗ Prediction: 'cafe/restaurant', should be 'grocery_store'
# 	So far, success rate: 62/136 (45.59 %)
# ✗ Prediction: 'cafe/restaurant', should be 'grocery_store'
# 	So far, success rate: 62/137 (45.26 %)
# ✗ Prediction: 'metro_station', should be 'home'
# 	So far, success rate: 62/138 (44.93 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 63/139 (45.32 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 64/140 (45.71 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 65/141 (46.10 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 66/142 (46.48 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 67/143 (46.85 %)
# ✗ Prediction: 'beach', should be 'home'
# 	So far, success rate: 67/144 (46.53 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 68/145 (46.90 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 69/146 (47.26 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 70/147 (47.62 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 71/148 (47.97 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 72/149 (48.32 %)
# ✗ Prediction: 'library', should be 'home'
# 	So far, success rate: 72/150 (48.00 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 73/151 (48.34 %)
# ✗ Prediction: 'library', should be 'home'
# 	So far, success rate: 73/152 (48.03 %)
# ✓ Prediction: 'home', should be 'home'
# 	So far, success rate: 74/153 (48.37 %)
# ✗ Prediction: 'library', should be 'home'
# 	So far, success rate: 74/154 (48.05 %)
# ✗ Prediction: 'library', should be 'home'
# 	So far, success rate: 74/155 (47.74 %)
# ✗ Prediction: 'grocery_store', should be 'library'
# 	So far, success rate: 74/156 (47.44 %)
# ✗ Prediction: 'grocery_store', should be 'library'
# 	So far, success rate: 74/157 (47.13 %)
# ✗ Prediction: 'grocery_store', should be 'library'
# 	So far, success rate: 74/158 (46.84 %)
# ✗ Prediction: 'grocery_store', should be 'library'
# 	So far, success rate: 74/159 (46.54 %)
# ✗ Prediction: 'residential_area', should be 'library'
# 	So far, success rate: 74/160 (46.25 %)
# ✗ Prediction: 'grocery_store', should be 'library'
# 	So far, success rate: 74/161 (45.96 %)
# ✗ Prediction: 'beach', should be 'library'
# 	So far, success rate: 74/162 (45.68 %)
# ✓ Prediction: 'library', should be 'library'
# 	So far, success rate: 75/163 (46.01 %)
# ✓ Prediction: 'library', should be 'library'
# 	So far, success rate: 76/164 (46.34 %)
# ✓ Prediction: 'library', should be 'library'
# 	So far, success rate: 77/165 (46.67 %)
# ✗ Prediction: 'home', should be 'library'
# 	So far, success rate: 77/166 (46.39 %)
# ✓ Prediction: 'library', should be 'library'
# 	So far, success rate: 78/167 (46.71 %)
# ✓ Prediction: 'library', should be 'library'
# 	So far, success rate: 79/168 (47.02 %)
# ✗ Prediction: 'metro_station', should be 'library'
# 	So far, success rate: 79/169 (46.75 %)
# ✓ Prediction: 'library', should be 'library'
# 	So far, success rate: 80/170 (47.06 %)
# ✗ Prediction: 'metro_station', should be 'library'
# 	So far, success rate: 80/171 (46.78 %)
# ✓ Prediction: 'library', should be 'library'
# 	So far, success rate: 81/172 (47.09 %)
# ✗ Prediction: 'metro_station', should be 'library'
# 	So far, success rate: 81/173 (46.82 %)
# ✗ Prediction: 'city_center', should be 'metro_station'
# 	So far, success rate: 81/174 (46.55 %)
# ✗ Prediction: 'office', should be 'metro_station'
# 	So far, success rate: 81/175 (46.29 %)
# ✗ Prediction: 'home', should be 'metro_station'
# 	So far, success rate: 81/176 (46.02 %)
# ✓ Prediction: 'metro_station', should be 'metro_station'
# 	So far, success rate: 82/177 (46.33 %)
# ✗ Prediction: 'home', should be 'metro_station'
# 	So far, success rate: 82/178 (46.07 %)
# ✓ Prediction: 'metro_station', should be 'metro_station'
# 	So far, success rate: 83/179 (46.37 %)
# ✓ Prediction: 'metro_station', should be 'metro_station'
# 	So far, success rate: 84/180 (46.67 %)
# ✓ Prediction: 'metro_station', should be 'metro_station'
# 	So far, success rate: 85/181 (46.96 %)
# ✗ Prediction: 'park', should be 'metro_station'
# 	So far, success rate: 85/182 (46.70 %)
# ✓ Prediction: 'metro_station', should be 'metro_station'
# 	So far, success rate: 86/183 (46.99 %)
# ✗ Prediction: 'cafe/restaurant', should be 'metro_station'
# 	So far, success rate: 86/184 (46.74 %)
# ✗ Prediction: 'park', should be 'metro_station'
# 	So far, success rate: 86/185 (46.49 %)
# ✓ Prediction: 'metro_station', should be 'metro_station'
# 	So far, success rate: 87/186 (46.77 %)
# ✓ Prediction: 'metro_station', should be 'metro_station'
# 	So far, success rate: 88/187 (47.06 %)
# ✓ Prediction: 'metro_station', should be 'metro_station'
# 	So far, success rate: 89/188 (47.34 %)
# ✗ Prediction: 'residential_area', should be 'metro_station'
# 	So far, success rate: 89/189 (47.09 %)
# ✗ Prediction: 'cafe/restaurant', should be 'metro_station'
# 	So far, success rate: 89/190 (46.84 %)
# ✗ Prediction: 'park', should be 'metro_station'
# 	So far, success rate: 89/191 (46.60 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 90/192 (46.88 %)
# ✗ Prediction: 'home', should be 'office'
# 	So far, success rate: 90/193 (46.63 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 91/194 (46.91 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 92/195 (47.18 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 93/196 (47.45 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 94/197 (47.72 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 95/198 (47.98 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 96/199 (48.24 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 97/200 (48.50 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 98/201 (48.76 %)
# ✗ Prediction: 'metro_station', should be 'office'
# 	So far, success rate: 98/202 (48.51 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 99/203 (48.77 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 100/204 (49.02 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 101/205 (49.27 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 102/206 (49.51 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 103/207 (49.76 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 104/208 (50.00 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 105/209 (50.24 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 106/210 (50.48 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 107/211 (50.71 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 108/212 (50.94 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 109/213 (51.17 %)
# ✓ Prediction: 'office', should be 'office'
# 	So far, success rate: 110/214 (51.40 %)
# ✗ Prediction: 'metro_station', should be 'park'
# 	So far, success rate: 110/215 (51.16 %)
# ✗ Prediction: 'metro_station', should be 'park'
# 	So far, success rate: 110/216 (50.93 %)
# ✗ Prediction: 'metro_station', should be 'park'
# 	So far, success rate: 110/217 (50.69 %)
# ✓ Prediction: 'park', should be 'park'
# 	So far, success rate: 111/218 (50.92 %)
# ✗ Prediction: 'home', should be 'park'
# 	So far, success rate: 111/219 (50.68 %)
# ✗ Prediction: 'library', should be 'park'
# 	So far, success rate: 111/220 (50.45 %)
# ✓ Prediction: 'park', should be 'park'
# 	So far, success rate: 112/221 (50.68 %)
# ✓ Prediction: 'park', should be 'park'
# 	So far, success rate: 113/222 (50.90 %)
# ✗ Prediction: 'library', should be 'park'
# 	So far, success rate: 113/223 (50.67 %)
# ✗ Prediction: 'library', should be 'park'
# 	So far, success rate: 113/224 (50.45 %)
# ✓ Prediction: 'park', should be 'park'
# 	So far, success rate: 114/225 (50.67 %)
# ✗ Prediction: 'home', should be 'park'
# 	So far, success rate: 114/226 (50.44 %)
# ✗ Prediction: 'city_center', should be 'park'
# 	So far, success rate: 114/227 (50.22 %)
# ✗ Prediction: 'city_center', should be 'park'
# 	So far, success rate: 114/228 (50.00 %)
# ✗ Prediction: 'city_center', should be 'park'
# 	So far, success rate: 114/229 (49.78 %)
# ✗ Prediction: 'city_center', should be 'park'
# 	So far, success rate: 114/230 (49.57 %)
# ✗ Prediction: 'city_center', should be 'park'
# 	So far, success rate: 114/231 (49.35 %)
# ✗ Prediction: 'city_center', should be 'park'
# 	So far, success rate: 114/232 (49.14 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/233 (48.93 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/234 (48.72 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/235 (48.51 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/236 (48.31 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/237 (48.10 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/238 (47.90 %)
# ✗ Prediction: 'tram', should be 'residential_area'
# 	So far, success rate: 114/239 (47.70 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/240 (47.50 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/241 (47.30 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/242 (47.11 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/243 (46.91 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 114/244 (46.72 %)
# ✓ Prediction: 'residential_area', should be 'residential_area'
# 	So far, success rate: 115/245 (46.94 %)
# ✗ Prediction: 'park', should be 'residential_area'
# 	So far, success rate: 115/246 (46.75 %)
# ✗ Prediction: 'forest_path', should be 'residential_area'
# 	So far, success rate: 115/247 (46.56 %)
# ✗ Prediction: 'forest_path', should be 'residential_area'
# 	So far, success rate: 115/248 (46.37 %)
# ✓ Prediction: 'residential_area', should be 'residential_area'
# 	So far, success rate: 116/249 (46.59 %)
# ✗ Prediction: 'forest_path', should be 'residential_area'
# 	So far, success rate: 116/250 (46.40 %)
# ✗ Prediction: 'forest_path', should be 'residential_area'
# 	So far, success rate: 116/251 (46.22 %)
# ✗ Prediction: 'forest_path', should be 'residential_area'
# 	So far, success rate: 116/252 (46.03 %)
# ✗ Prediction: 'forest_path', should be 'residential_area'
# 	So far, success rate: 116/253 (45.85 %)
# ✗ Prediction: 'home', should be 'train'
# 	So far, success rate: 116/254 (45.67 %)
# ✗ Prediction: 'bus', should be 'train'
# 	So far, success rate: 116/255 (45.49 %)
# ✗ Prediction: 'bus', should be 'train'
# 	So far, success rate: 116/256 (45.31 %)
# ✗ Prediction: 'beach', should be 'train'
# 	So far, success rate: 116/257 (45.14 %)
# ✓ Prediction: 'train', should be 'train'
# 	So far, success rate: 117/258 (45.35 %)
# ✗ Prediction: 'bus', should be 'train'
# 	So far, success rate: 117/259 (45.17 %)
# ✗ Prediction: 'bus', should be 'train'
# 	So far, success rate: 117/260 (45.00 %)
# ✗ Prediction: 'tram', should be 'train'
# 	So far, success rate: 117/261 (44.83 %)
# ✗ Prediction: 'car', should be 'train'
# 	So far, success rate: 117/262 (44.66 %)
# ✗ Prediction: 'tram', should be 'train'
# 	So far, success rate: 117/263 (44.49 %)
# ✓ Prediction: 'train', should be 'train'
# 	So far, success rate: 118/264 (44.70 %)
# ✗ Prediction: 'tram', should be 'train'
# 	So far, success rate: 118/265 (44.53 %)
# ✓ Prediction: 'train', should be 'train'
# 	So far, success rate: 119/266 (44.74 %)
# ✓ Prediction: 'train', should be 'train'
# 	So far, success rate: 120/267 (44.94 %)
# ✗ Prediction: 'beach', should be 'train'
# 	So far, success rate: 120/268 (44.78 %)
# ✓ Prediction: 'train', should be 'train'
# 	So far, success rate: 121/269 (44.98 %)
# ✗ Prediction: 'tram', should be 'train'
# 	So far, success rate: 121/270 (44.81 %)
# ✓ Prediction: 'train', should be 'train'
# 	So far, success rate: 122/271 (45.02 %)
# ✓ Prediction: 'train', should be 'train'
# 	So far, success rate: 123/272 (45.22 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 124/273 (45.42 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 125/274 (45.62 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 126/275 (45.82 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 127/276 (46.01 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 128/277 (46.21 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 129/278 (46.40 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 130/279 (46.59 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 131/280 (46.79 %)
# ✗ Prediction: 'bus', should be 'tram'
# 	So far, success rate: 131/281 (46.62 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 132/282 (46.81 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 133/283 (47.00 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 134/284 (47.18 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 135/285 (47.37 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 136/286 (47.55 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 137/287 (47.74 %)
# ✗ Prediction: 'park', should be 'tram'
# 	So far, success rate: 137/288 (47.57 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 138/289 (47.75 %)
# ✓ Prediction: 'tram', should be 'tram'
# 	So far, success rate: 139/290 (47.93 %)
# Done. Success rate: 139/290 (47.93 %)

# %% [markdown]
# ## Prediction of unknown data:

# %%
os.remove("prediction.txt")

for i, row in unknown_set.iterrows():
    prediction = predict(row.filename, votes, best_clf, n_coefs=n_coefs, n_vect=n_vectors)
    #print("Prediction: '%s'" % prediction)
    with open("prediction.txt", "a+") as f:
        f.write(str(labels_numbers[prediction]) + '\n')
    if i%10 == 0:
        print("Predicted %d/%d (%.0f %%)" % (i, len(unknown_set), i/len(unknown_set) * 100))
print("Finished")
# Out:
# Predicted 0/298 (0 %)
# Predicted 10/298 (3 %)
# Predicted 20/298 (7 %)
# Predicted 30/298 (10 %)
# Predicted 40/298 (13 %)
# Predicted 50/298 (17 %)
# Predicted 60/298 (20 %)
# Predicted 70/298 (23 %)
# Predicted 80/298 (27 %)
# Predicted 90/298 (30 %)
# Predicted 100/298 (34 %)
# Predicted 110/298 (37 %)
# Predicted 120/298 (40 %)
# Predicted 130/298 (44 %)
# Predicted 140/298 (47 %)
# Predicted 150/298 (50 %)
# Predicted 160/298 (54 %)
# Predicted 170/298 (57 %)
# Predicted 180/298 (60 %)
# Predicted 190/298 (64 %)
# Predicted 200/298 (67 %)
# Predicted 210/298 (70 %)
# Predicted 220/298 (74 %)
# Predicted 230/298 (77 %)
# Predicted 240/298 (81 %)
# Predicted 250/298 (84 %)
# Predicted 260/298 (87 %)
# Predicted 270/298 (91 %)
# Predicted 280/298 (94 %)
# Predicted 290/298 (97 %)
